# %% [markdown]
# # General debugging

# %%
from alm.utils import FullAtomisticLanguageDataset
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
llm = AutoModelForCausalLM.from_pretrained(
    'Qwen/Qwen3-8B',
    torch_dtype=torch.bfloat16, # let's stick with b16 for now.
    attn_implementation='flash_attention_2'
)
tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen3-8B')
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
dataset = FullAtomisticLanguageDataset(tokenizer, 'validation', '/home/sathya/Data/LLM4Mat-Bench/data', thinking=False, max_num_tokens=1024)
# Out:
# ...
# Building index for dataset: 100%|██████████| 1037/1037 [00:00<00:00, 10558.10it/s]

# %%
len(dataset)
# Out:
# 238754

# %%
dataset[238753]['atom_rows'][0].toatoms()
# Out:
# Atoms(symbols='O12H24', pbc=True, cell=[6.55668748, 6.55668748, 6.93024844])
